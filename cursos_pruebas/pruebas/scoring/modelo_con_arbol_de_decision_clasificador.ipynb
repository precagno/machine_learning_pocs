# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

model_data = pd.read_csv('dataset/train_clean.csv')

# %%
model_data_clean = model_data[pd.notnull(model_data['Num_of_Delayed_Payment'])]
X = model_data_clean.drop(columns=['Credit_Score','ID','Month','Name','Payment_Behaviour'])
y = model_data_clean['Credit_Score']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
#      Age  Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 299   37          12       15566.02           1.423168e+03                  8
# 225   37          10       39641.54           3.007462e+03                 10
# 106   39          10     8701545.00           5.191287e+02                  6
# 373   43           6       81842.28           6.810190e+03                 10
# 294   36          12       15566.02           1.423168e+03                  8
# ..   ...         ...            ...                    ...                ...
# 415   36          14       17251.38           1.654615e+06                  6
# 150   32           4       19300.34           1.512362e+03                  6
# 286   19           3       72559.36           6.284613e+03                  4
# 176   20           4      106733.13           8.873427e+03                  4
# 186   34          13       57983.12           4.720927e+03                  9
#
# ...

# %%
X_test
# Out:
#      Age  Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 88    33           3       88640.24           7.266687e+03                  3
# 115   37           4       25546.26           2.415855e+06                  8
# 372   43           6       81842.28           6.810190e+03                 10
# 208   32          11       43070.24           3.622187e+03                  3
# 199   30          14       34290.12           2.697510e+03                  9
# ..   ...         ...            ...                    ...                ...
# 365   30           2       87215.68           7.489973e+03                  2
# 61    23           8      114838.41           9.843868e+03                  2
# 100   39          10     8701545.00           5.191287e+02                  6
# 154   41          12       19514.88           1.828240e+03                  7
# 413   43           5      123732.32           1.041603e+04                  4
#
# ...

# %%
y_train
# Out:
# 299    0
# 225    0
# 106    0
# 373    1
# 294    0
#       ..
# 415    1
# 150    0
# 286    1
# 176    1
# 186    1
# Name: Credit_Score, Length: 316, dtype: int64

# %%
y_test
# Out:
# 88     2
# 115    1
# 372    1
# 208    1
# 199    0
#       ..
# 365    2
# 61     2
# 100    0
# 154    1
# 413    1
# Name: Credit_Score, Length: 79, dtype: int64

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
model
# Out:
# DecisionTreeClassifier()

# %%
predictions = model.predict(X_test)

predictions
# Out:
# array([1, 1, 1, 1, 0, 2, 0, 2, 0, 1, 2, 1, 0, 0, 1, 1, 0, 2, 1, 1, 1, 1,
#        1, 1, 2, 0, 1, 0, 2, 1, 0, 2, 1, 1, 0, 1, 1, 0, 1, 0, 1, 1, 1, 1,
#        1, 1, 1, 2, 1, 1, 1, 1, 1, 2, 2, 1, 1, 1, 1, 1, 0, 1, 0, 2, 1, 1,
#        1, 1, 1, 1, 0, 2, 0, 0, 2, 2, 0, 0, 1])

# %%
score = accuracy_score(y_test, predictions)
score
# Out:
# 0.7468354430379747
